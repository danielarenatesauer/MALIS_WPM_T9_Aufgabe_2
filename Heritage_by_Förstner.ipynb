# %%
import pandas as pd

# %%
heritage_data = pd.read_csv("A_Heritage Vol.2 n.3 ZOTERO.csv")

# %%
heritage_data.head()
# Out:
#         Key       Item Type  Publication Year  \
# 0  ATUZDD76  journalArticle              2019
# 1  5N5WGR96  journalArticle              2019
# 2  EEVH9NY4  journalArticle              2019
# 3  ZFNESXP6  journalArticle              2019
# 4  SKFNBAD9  journalArticle              2019
#
#                                               Author  \
# 0                                      Bronec, Jakub
# 1  Kargas, Antonios; Loumos, Georgios; Varoutas, ...
# 2                             Chen, Otto; Han, Dawei
# 3                   Rahaman, Hafizur; Champion, Erik
# 4  Torrisi, Lorenzo; Venuti, Valentina; Crupi, Vi...
#
#                                                Title Publication Title  ISBN  \
# 0  Transmission of Collective Memory and Jewish I...          Heritage   NaN
# 1  Using Different Ways of 3D Reconstruction of H...          Heritage   NaN
# 2  Rediscovering the Idea of Cultural Heritage an...          Heritage   NaN
# ...

# %%
heritage_data = heritage_data.drop("Author", axis=1)

# %%
heritage_data.to_csv("Heritage_without_authors.csv")
