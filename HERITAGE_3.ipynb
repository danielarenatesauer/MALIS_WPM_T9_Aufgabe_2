# %%
import urllib.request
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/danielarenatesauer/MALIS_WPM_T9_Aufgabe_2/master/A_Heritage%20Vol.2%20n.3%20ZOTERO.csv"
journal_file = "Heritage_3.csv"

# %%
urllib.request.urlretrieve(url, journal_file)
# Out:
# ('Heritage_3.csv', <http.client.HTTPMessage at 0x12110b898>)

# %%
for line in  open(journal_file):
    print (line)
# Out:
# "Key","Item Type","Publication Year","Author","Title","Publication Title","ISBN","ISSN","DOI","Url","Abstract Note","Date","Access Date","Pages","Num Pages","Issue","Volume"
#
# "ATUZDD76","journalArticle","2019","Bronec, Jakub","Transmission of Collective Memory and Jewish Identity in Post-War Jewish Generations through War Souvenirs","Heritage","","2571-9408","10.3390/heritage2030109","https://www.mdpi.com/2571-9408/2/3/109","","2019","2019-07-21 13:35:24","2019-07-21 13:35:24","1785–1798","3","2"
#
# "5N5WGR96","journalArticle","2019","Kargas, Antonios; Loumos, Georgios; Varoutas, Dimitrios","Using Different Ways of 3D Reconstruction of Historical Cities for Gaming Purposes: The Case Study of Nafplio","Heritage","","2571-9408","10.3390/heritage2030110","https://www.mdpi.com/2571-9408/2/3/110","","2019","2019-07-21 13:35:25","2019-07-21 13:35:25","1799–1811","3","2"
#
# ...

# %%
articles = pd.read_csv(journal_file)

# %%
print(articles)
# Out:
#          Key       Item Type  Publication Year  \
# 0   ATUZDD76  journalArticle              2019
# 1   5N5WGR96  journalArticle              2019
# 2   EEVH9NY4  journalArticle              2019
# 3   ZFNESXP6  journalArticle              2019
# 4   SKFNBAD9  journalArticle              2019
# 5   KUUCJM72  journalArticle              2019
# 6   5Q3QWURP  journalArticle              2019
# 7   6IDJREGV  journalArticle              2019
# 8   GH9DEKT7  journalArticle              2019
# 9   FT8ZUFKZ  journalArticle              2019
# 10  XYRHWTER  journalArticle              2019
# 11  3CZYNT9C  journalArticle              2019
# 12  7GQEBH5F  journalArticle              2019
# 13  ACXJQ3ZZ  journalArticle              2019
#
#                                                Author  \
# 0                                       Bronec, Jakub
# 1   Kargas, Antonios; Loumos, Georgios; Varoutas, ...
# 2                              Chen, Otto; Han, Dawei
# ...

# %%
articles
# Out:
#          Key       Item Type  Publication Year  \
# 0   ATUZDD76  journalArticle              2019
# 1   5N5WGR96  journalArticle              2019
# 2   EEVH9NY4  journalArticle              2019
# 3   ZFNESXP6  journalArticle              2019
# 4   SKFNBAD9  journalArticle              2019
# 5   KUUCJM72  journalArticle              2019
# 6   5Q3QWURP  journalArticle              2019
# 7   6IDJREGV  journalArticle              2019
# 8   GH9DEKT7  journalArticle              2019
# 9   FT8ZUFKZ  journalArticle              2019
# 10  XYRHWTER  journalArticle              2019
# 11  3CZYNT9C  journalArticle              2019
# 12  7GQEBH5F  journalArticle              2019
# 13  ACXJQ3ZZ  journalArticle              2019
#
#                                                Author  \
# 0                                       Bronec, Jakub
# 1   Kargas, Antonios; Loumos, Georgios; Varoutas, ...
# 2                              Chen, Otto; Han, Dawei
# ...

# %%
articles.shape
# Out:
# (14, 17)

# %%
articles.columns
# Out:
# Index(['Key', 'Item Type', 'Publication Year', 'Author', 'Title',
#        'Publication Title', 'ISBN', 'ISSN', 'DOI', 'Url', 'Abstract Note',
#        'Date', 'Access Date', 'Pages', 'Num Pages', 'Issue', 'Volume'],
#       dtype='object')

# %%
articles [['Publication Year','Author','Title','Publication Title','ISSN','DOI','Url','Abstract Note','Num Pages','Issue','Volume']]
# Out:
#     Publication Year                                             Author  \
# 0               2019                                      Bronec, Jakub
# 1               2019  Kargas, Antonios; Loumos, Georgios; Varoutas, ...
# 2               2019                             Chen, Otto; Han, Dawei
# 3               2019                   Rahaman, Hafizur; Champion, Erik
# 4               2019  Torrisi, Lorenzo; Venuti, Valentina; Crupi, Vi...
# 5               2019                                 Tawab, Ayman Abdel
# 6               2019  Gaitán, Mar; Alba, Ester; León, Arabella; Pére...
# 7               2019                          Nikolopoulou, Konstantina
# 8               2019  Cuperschmid, Ana Regina Mizrahy; Fabricio, Már...
# 9               2019      Shimoda, Ichita; Uchida, Etsuo; Tsuda, Kojiro
# 10              2019   Mazurek, Joy; Svoboda, Marie; Schilling, Michael
# 11              2019  Gizzi, Fabrizio Terenzio; Biscione, Marilisa; ...
# ...
